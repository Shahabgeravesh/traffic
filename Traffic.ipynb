# %%
#Imported the libraries 

import pandas as pd
import matplotlib.pyplot as plt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# read the table with Spark
data=sqlContext.sql("select * from traffic")
# Converted spark to pandas dataframe 
pandas_data=data.toPandas()
data=pandas_data 
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>crash_record_id</th>
#       <th>rd_no</th>
#       <th>crash_date_est_i</th>
#       <th>crash_date</th>
#       <th>posted_speed_limit</th>
#       <th>traffic_control_device</th>
#       <th>device_condition</th>
#       <th>weather_condition</th>
#       <th>lighting_condition</th>
#       <th>first_crash_type</th>
#       <th>trafficway_type</th>
#       <th>lane_cnt</th>
#       <th>alignment</th>
#       <th>roadway_surface_cond</th>
#       <th>road_defect</th>
#       <th>report_type</th>
#       <th>crash_type</th>
#       <th>intersection_related_i</th>
#       <th>not_right_of_way_i</th>
# ...

# %%
data.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 153541 entries, 0 to 153540
# Data columns (total 52 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   crash_record_id                153541 non-null  object
#  1   rd_no                          151808 non-null  object
#  2   crash_date_est_i               10307 non-null   object
#  3   crash_date                     153541 non-null  object
#  4   posted_speed_limit             153541 non-null  object
#  5   traffic_control_device         153541 non-null  object
# ...

# %%
data.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>crash_record_id</th>
#       <th>rd_no</th>
#       <th>crash_date_est_i</th>
#       <th>crash_date</th>
#       <th>posted_speed_limit</th>
#       <th>traffic_control_device</th>
#       <th>device_condition</th>
#       <th>weather_condition</th>
#       <th>lighting_condition</th>
#       <th>first_crash_type</th>
#       <th>trafficway_type</th>
#       <th>lane_cnt</th>
#       <th>alignment</th>
#       <th>roadway_surface_cond</th>
#       <th>road_defect</th>
#       <th>report_type</th>
#       <th>crash_type</th>
#       <th>intersection_related_i</th>
#       <th>not_right_of_way_i</th>
# ...

# %%
data.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: (153541, 52)</div>

# %%
data_missing=data.isna()
data_missing=data_missing.sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Calculate the missing percentage
data_missing_percentage=(data_missing/len(data))*100
data_missing_percentage
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: crash_record_id                    0.000000
# rd_no                              1.128689
# crash_date_est_i                  93.287135
# crash_date                         0.000000
# posted_speed_limit                 0.000000
# traffic_control_device             0.000000
# device_condition                   0.000000
# weather_condition                  0.000000
# lighting_condition                 0.000000
# first_crash_type                   0.000000
# trafficway_type                    0.000000
# lane_cnt                          53.743300
# alignment                          0.000000
# ...

# %%
data.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: crash_record_id                  object
# rd_no                            object
# crash_date_est_i                 object
# crash_date                       object
# posted_speed_limit               object
# traffic_control_device           object
# device_condition                 object
# weather_condition                object
# lighting_condition               object
# first_crash_type                 object
# trafficway_type                  object
# lane_cnt                         object
# alignment                        object
# roadway_surface_cond             object
# road_defect                      object
# ...
